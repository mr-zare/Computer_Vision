# %%
import numpy as np
import matplotlib.image as mlimg
import matplotlib.pyplot as plt
import cv2
import os

# %%
image=cv2.imread("Q1.jpg")
print(image.shape)
cv2.imshow("image",image)
#image2=mlimg.imread("C:\Users\ASUS\Desktop\hw0\HW0\Q1.JPG")
#imgr = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#plt.imshow(img,cmap='gray')
#plt.show()
plt.imshow(image)
#show_img.show()
plt.axis('off')
plt.show()
cv2.waitKey()
# Out:
# (680, 1020, 3)
# -1

# %%
#https://www.geeksforgeeks.org/create-a-directory-in-python/
#https://stackoverflow.com/questions/18262293/how-to-open-every-file-in-a-folder
#https://www.entechin.com/how-to-convert-an-image-to-black-and-white-in-python/#:~:text=If%20you%20want%20to%20transform,the%20image%20to%20grayscale%20mode.

folder="emptyfolder"
directory="Q1"
new_path=os.path.join(directory,folder)
os.makedirs(new_path)
for names in os.listdir(os.getcwd()):
    with open(os.path.join(os.getcwd(),names),'r') as a
    ftxt=os.path.join(names,".txt")
    f=open(ftxt,'w')
    size_pic=a.shape()
    f.write(size_pic)
    pic=a.convert('L')
    path_pic=os.path.join(names,"blackwhite")
    new_pic=os.pa.join(path_pic,".jpg")
    a.save(new_pic)
